# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("../data/calibration/data.txt", skip_header=2)


top_Ex_ref = data[0::2, 1]
top_Ey_ref = data[0::2, 2]
top_Ez_ref = data[0::2, 3]
top_Ewx = data[0::2, 4]
top_Ewy = data[0::2, 5]
top_Ewz = data[0::2, 6]

bot_Ex_ref = data[1::2, 1]
bot_Ey_ref = data[1::2, 2]
bot_Ez_ref = data[1::2, 3]
bot_Ewx = data[1::2, 4]
bot_Ewy = data[1::2, 5]
bot_Ewz = data[1::2, 6]

# %%
plt.plot(bot_Ex_ref, bot_Ewx, ".")
plt.show()
plt.plot(bot_Ey_ref, bot_Ewy, ".")
plt.show()
plt.plot(bot_Ez_ref, bot_Ewz, ".")
plt.show()

# %%
plt.plot(bot_Ewx)
plt.show()
plt.plot(bot_Ewy)
plt.show()
plt.plot(bot_Ewz)
plt.show()

# %%
plt.plot(bot_Ex_ref)
plt.show()
plt.plot(bot_Ey_ref)
plt.show()
plt.plot(bot_Ez_ref)
plt.show()
