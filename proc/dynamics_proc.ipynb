# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def display_with_mean(ts: np.array, data: np.array, title: str, y_label: str):
    t_min = np.min(ts)
    t_max = np.max(ts)

    plt.figure(dpi=100)
    plt.title(f"{title}")
    plt.xlabel(r"$t, ns$")
    plt.ylabel(f"{y_label}")
    plt.grid()
    plt.plot(ts, data, "-")
    plt.hlines(
        np.mean(data[1_000:]),
        1.1 * t_min,
        t_max,
        colors="red",
        linestyles="--",
        label=f"{np.mean(data[1_000:]):10f}",
    )
    plt.legend(loc="best")
    plt.show()

    return np.mean(data[1_000:])

# %%
data = np.genfromtxt(f"../data/dynamics/data.txt", delimiter="\t")

rs_1 = np.sqrt(np.square(data[:, 1]) + np.square(data[:, 2]))
rs_2 = np.sqrt(np.square(data[:, 4]) + np.square(data[:, 5]))
zs_1 = data[:, 3]
vzs_1 = data[:, 6]

vs_1 = np.sqrt(np.square(data[:, 7]) + np.square(data[:, 8]))
vs_2 = np.sqrt(np.square(data[:, 7 + 3]) + np.square(data[:, 8 + 3]))
zs_2 = data[:, 9]
vzs_2 = data[:, 12]

t = (data[:, 0]) / 2.0 * 50.0
t_min = np.min(t)
t_max = np.max(t)

k_B = 1.380649e-23  # Boltzmann constant (J/K)
m_i = 6.6335209e-26  # Ar+ ions' mass (kg)
P = 0.25 * 18.131842  # Pressure (Pascal)
r_D_e = 0.0016622715189364113

dphis = []
for i in range(len(data[:, 1])):
    dphis += [
        np.dot(
            np.array([data[i, 1], data[i, 2]]),
            np.array([data[i, 4], data[i, 5]]),
        )
        / rs_1[i]
        / rs_2[i]
    ]
dphis = np.array(dphis)

display_with_mean(t, rs_1 / r_D_e, "1st", "r, r_D_e")
display_with_mean(t, rs_2 / r_D_e, "2nd", "r, r_D_e")
display_with_mean(t, vs_1, "1st", "v, m/s")
display_with_mean(t, vs_2, "2nd", "v, m/s")


display_with_mean(t, dphis, "a", "phi")

display_with_mean(t, zs_1 / r_D_e, "1st", "r, r_D_e")
display_with_mean(t, zs_2 / r_D_e, "2nd", "r, r_D_e")
display_with_mean(t, vzs_1, "1st", "v, m/s")
display_with_mean(t, vzs_2, "2nd", "v, m/s")
# Out:
# np.float64(1.5928228485315335e-07)

# %%
data = np.genfromtxt(f"../data/dynamics/data_onc.txt", delimiter="\t")

rs_1 = np.sqrt(np.square(data[:, 1]) + np.square(data[:, 2]))
rs_2 = np.sqrt(np.square(data[:, 4]) + np.square(data[:, 5]))
zs_1 = data[:, 3]
vzs_1 = data[:, 6]

vs_1 = np.sqrt(np.square(data[:, 7]) + np.square(data[:, 8]))
vs_2 = np.sqrt(np.square(data[:, 7 + 3]) + np.square(data[:, 8 + 3]))
zs_2 = data[:, 9]
vzs_2 = data[:, 12]

t = (data[:, 0]) / 2.0 * 50.0
t_min = np.min(t)
t_max = np.max(t)

k_B = 1.380649e-23  # Boltzmann constant (J/K)
m_i = 6.6335209e-26  # Ar+ ions' mass (kg)
P = 0.25 * 18.131842  # Pressure (Pascal)
r_D_e = 0.0016622715189364113

# smpl_dphi = []
# for i in range(len(smpl_data[:, 1])):
#     smpl_dphi += [
#         np.dot(
#             np.array([smpl_data[i, 1], smpl_data[i, 2]]),
#             np.array([smpl_data[i, 10], smpl_data[i, 11]]),
#         )
#         / smpl_rs_1[i]
#         / smpl_rs_2[i]
#     ]
# smpl_dphi = np.array(smpl_dphi)

display_with_mean(t, rs_1, "1st", "r, r_D_e")
display_with_mean(t, rs_2, "2nd", "r, r_D_e")
display_with_mean(t, vs_1, "1st", "v, m/s")
display_with_mean(t, vs_2, "2nd", "v, m/s")

display_with_mean(t, zs_1, "1st", "r, r_D_e")
display_with_mean(t, zs_2, "2nd", "r, r_D_e")
display_with_mean(t, vzs_1, "1st", "v, m/s")
display_with_mean(t, vzs_2, "2nd", "v, m/s")
# Out:
# np.float64(-6.806921148414386e-08)

# %%
# cmpl_data = np.genfromtxt("./new_data_cmpl/data.txt", delimiter="\t"))
# r1 = 0.000340
# r2 = 0.000127
# z1 = 0.003187
# z2 = 0.002788
# v1 = 0.024
# v2 = 0.00895
# vz1 = 0
# vz2 = 0

for j in range(1, 100 + 1):
    smpl_data = np.genfromtxt(f"../data/dynamics/data_{j}.txt", delimiter="\t")

    smpl_rs_1 = np.sqrt(np.square(smpl_data[:, 1]) + np.square(smpl_data[:, 2]))
    smpl_rs_2 = np.sqrt(np.square(smpl_data[:, 4]) + np.square(smpl_data[:, 5]))

    zs_1 = smpl_data[:, 3]
    zs_2 = smpl_data[:, 6]

    vs_1 = np.sqrt(np.square(smpl_data[:, 7]) + np.square(smpl_data[:, 8]))
    vs_2 = np.sqrt(np.square(smpl_data[:, 10]) + np.square(smpl_data[:, 11]))

    vzs_1 = smpl_data[:, 9]
    vzs_2 = smpl_data[:, 12]

    t = (smpl_data[:, 0]) / 2.0 * 50.0
    t_min = np.min(t)
    t_max = np.max(t)

    k_B = 1.380649e-23  # Boltzmann constant (J/K)
    m_i = 6.6335209e-26  # Ar+ ions' mass (kg)
    P = 0.25 * 18.131842  # Pressure (Pascal)
    r_D_e = 0.0016622715189364113

    # smpl_dphi = []
    # for i in range(len(smpl_data[:, 1])):
    #     smpl_dphi += [
    #         np.dot(
    #             np.array([smpl_data[i, 1], smpl_data[i, 2]]),
    #             np.array([smpl_data[i, 10], smpl_data[i, 11]]),
    #         )
    #         / smpl_rs_1[i]
    #         / smpl_rs_2[i]
    #     ]
    # smpl_dphi = np.array(smpl_dphi)

    # display_with_mean(t, smpl_rs_1, "1st", "r, r_D_e")
    display_with_mean(t, smpl_rs_1, f"2nd_{j}", "r, r_D_e")

    # plt.figure(dpi=100)
    # plt.title("Simple model first particle")
    # plt.xlabel(r"$t, ns$")
    # plt.ylabel(r"$r, r_{D_e}$")
    # plt.grid()
    # plt.plot(t, smpl_rs_1, "-")
    # plt.hlines(
    #     np.mean(smpl_rs_1[1_000:]), 1.1 * t_min, t_max, colors="red", linestyles="--"
    # )

    # plt.title("Simple model second particle")
    # plt.xlabel(r"$t, ns$")
    # plt.ylabel(r"$r, r_{D_e}$")
    # plt.grid()
    # plt.plot(t, smpl_rs_2, "-")
    # plt.hlines(
    #     np.mean(smpl_rs_2[1_000:]), 1.1 * t_min, t_max, colors="red", linestyles="--"
    # )
    # plt.show()

    # print(f"r1={np.mean(smpl_rs_1[1_000:])}, r2={np.mean(smpl_rs_2[1_000:])}")

    # plt.figure(dpi=100)
    # plt.title(f"Simple model_{j}")
    # plt.xlabel(r"$t, ns$")
    # plt.ylabel(r"$\Delta \phi$")
    # plt.grid()
    # plt.plot(t, np.arccos(-smpl_dphi) * 360 / 2 / np.pi)
    # plt.show()
